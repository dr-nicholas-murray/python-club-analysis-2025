# %% [markdown]
# <a href="https://colab.research.google.com/github/dr-nicholas-murray/python-club-analysis-2025/blob/main/VCCRI_PythonClub_Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Let's represent data for a single patient
patient_id = 'P001' # A string (str) for text labels
age = 68 # An integer (int) for whole numbers
bmi = 29.3 # A float for decimal numbers
is_male = True # A boolean (bool) for True / False

# %%
print(f"the patient id is {patient_id}")
# Out:
# the patient id is P001

# %%
# A dictionary representing one patient record
patient_record = {
    "patient_id" : "P001",
    "age" : "68",
    "treatment_group": "A",
    "c_reactive_protein": 120
}

# %%
# Access data using its key
patient_age = patient_record["age"]
print(f"The age of this patient is: {patient_age}")
# Out:
# The age of this patient is: 68

# %%
# A small version of our full dataset
patient_cohort = [
    {"patient_id": "P001", "age": 68, "treatment_group": "A"},
    {"patient_id": "P002", "age": 75, "treatment_group": "B"},
    {"patient_id": "P003", "age": 52, "treatment_group": "A"}
]

# %%
# Access the first patient 's record using index 0
first_patient = patient_cohort[0]

# %%
# Access a specific piece of data from that record
first_patient_age = first_patient["age"]
print(first_patient_age)
print(f"First patient's age is: {first_patient_age}")
# Out:
# 68
# First patient's age is: 68

# %%
# Import the drive tool from google.colab
from google.colab import drive
# Mount Google Drive to access files at '/content/drive'
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import the pandas library and give it the standard alias 'pd'
import pandas as pd

# %%
# Define the path to our data file in Google Drive
# We break the long string into two lines for readability
file_path = ('/content/drive/MyDrive/VCCRI_Python_Club_2025/'
'data/pneumonia_recovery_dataset.csv')
# Use the pandas read_csv function to load the data
df = pd.read_csv(file_path)
# Confirm that the data has been loaded
print ("Dataset loaded successfully into a DataFrame!")
# Out:
# Dataset loaded successfully into a DataFrame!

# %%
# The .head() method displays the first 5 rows
# It's a quick way to inspect your columns and data
print("Displaying the first 5 rows of the patient data:")
df.head()
# Out:
# Displaying the first 5 rows of the patient data:
#   patient_id  age     sex   bmi  blood_pressure_systolic  hemoglobin_level  \
# 0       P001   68    Male  29.3                      145              13.1
# 1       P002   75  Female  24.1                      160              11.9
# 2       P003   52    Male  33.5                      130              15.2
# 3       P004   61  Female  21.9                      135              12.5
# 4       P005   79    Male  26.8                      155              11.5
#
#    c_reactive_protein treatment_group  days_to_recovery
# 0                 120               A                14
# 1                 155               B                18
# 2                  80               A                10
# 3                 110               B                12
# 4                 200               B                21
